# %% [markdown]
# # Task 3 - Feature Engineering
#
# **Overview:**
# This notebook is dedicated to the feature engineering phase of building a credit scoring model for Bati Bank’s Buy-Now-Pay-Later (BNPL) service. Feature engineering is a crucial step in transforming raw data into meaningful inputs that enhance model performance. The notebook walks through the process of creating new features, handling missing values, and preparing the dataset for further modeling.
#
# **Contents:**
#
# 1. **Create Aggregate Features:**
#    Summarizing transactional data to generate higher-level insights at the customer level, providing a more comprehensive view of customer behavior.
#
# 2. **Extract Features:**
#    Deriving additional information from existing data, such as time-based patterns, to better understand customer transaction habits and identify trends.
#
# 3. **Encode Categorical Variables:**
#    Transforming categorical variables into numerical representations to make them suitable for machine learning models.
#
# 4. **Handle Missing Values:**
#    Applying strategies to manage missing data, ensuring that gaps in the dataset do not negatively impact model performance.
#
# 5. **Normalize/Standardize Numerical Features:**
#    Scaling numerical features to ensure consistency across the dataset, allowing the model to perform optimally during training.
#
# ---
#
# This notebook provides a detailed explanation and step-by-step code implementations for these tasks, with visualizations included to aid in understanding the effects of feature engineering on the data. The ultimate goal is to prepare the dataset in a way that maximizes the accuracy and reliability of the credit scoring model.

# %% [markdown]
# # Importing Libaries

# %%
import pandas as pd
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../scripts')))

# %%
from feature_engineering import *

# %% [markdown]
# * Loading The Dataset

# %%
df = pd.read_csv('../data/data.csv')

# %% [markdown]
# # Creating Aggregate Features

# %%
agg_features = AggregateFeatures(df)

# %% [markdown]
# Total Transaction Amount: Sum of all transaction amounts for each customer.

# %%
agg_features.sum_all_transactions()

# %% [markdown]
# Average Transaction Amount: Average transaction amount per customer.

# %%
agg_features.average_transaction_amount()

# %% [markdown]
# Transaction Count: Number of transactions per customer.

# %%
agg_features.transaction_count()

# %% [markdown]
# Standard Deviation of Transaction Amounts: Variability of transaction amounts per customer.

# %%
agg_features.standard_deviation_amount()

# %% [markdown]
# ## Result after Aggregation

# %%
agg_df = agg_features.get_dataframe()
agg_df.head()
# Out:
#          TransactionId         BatchId       AccountId       SubscriptionId  \
# 0  TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1  TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2  TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3    TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4  TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1  CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2  CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3   CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4   CustomerId_988          UGX          256  ProviderId_4   ProductId_6
#
#       ProductCategory    ChannelId   Amount  Value  TransactionStartTime  \
# 0             airtime  ChannelId_3   1000.0   1000  2018-11-15T02:18:49Z
# 1  financial_services  ChannelId_2    -20.0     20  2018-11-15T02:19:08Z
# 2             airtime  ChannelId_3    500.0    500  2018-11-15T02:44:21Z
# 3        utility_bill  ChannelId_3  20000.0  21800  2018-11-15T03:32:55Z
# 4  financial_services  ChannelId_2   -644.0    644  2018-11-15T03:34:21Z
#
#    PricingStrategy  FraudResult  TotalTransactionAmount  \
# 0                2            0               109921.75
# 1                2            0               109921.75
# 2                2            0                 1000.00
# 3                2            0               228727.20
# 4                2            0               228727.20
#
#    AverageTransactionAmount  TotalTransactions  StdTransactionAmount
# 0                923.712185                119           3042.294251
# 1                923.712185                119           3042.294251
# 2                500.000000                  2              0.000000
# 3               6019.136842                 38          17169.241610
# 4               6019.136842                 38          17169.241610

# %% [markdown]
# # Extracting Features

# %%
extracted_features = Extracting_features(agg_df)

# %% [markdown]
# Transaction Hour: The hour of the day when the transaction occurred.

# %%
extracted_features.transaction_hour()

# %% [markdown]
# Transaction Day: The day of the month when the transaction occurred.

# %%
extracted_features.transaction_day()

# %% [markdown]
# Transaction Month: The month when the transaction occurred.

# %%
extracted_features.transaction_month()

# %% [markdown]
# Transaction Year: The year when the transaction occurred.

# %%
extracted_features.transaction_year()

# %% [markdown]
# # Result of the date feature extraction

# %%
extracted_features.get_dataframe()
# Out:
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# 95657   TransactionId_89881   BatchId_96668  AccountId_4841
# 95658   TransactionId_91597    BatchId_3503  AccountId_3439
# 95659   TransactionId_82501  BatchId_118602  AccountId_4841
# 95660  TransactionId_136354   BatchId_70924  AccountId_1346
# 95661   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# 0       SubscriptionId_887  CustomerId_4406          UGX          256
# 1      SubscriptionId_3829  CustomerId_4406          UGX          256
# 2       SubscriptionId_222  CustomerId_4683          UGX          256
# 3      SubscriptionId_2185   CustomerId_988          UGX          256
# 4      SubscriptionId_3829   CustomerId_988          UGX          256
# ...                    ...              ...          ...          ...
# 95657  SubscriptionId_3829  CustomerId_3078          UGX          256
# 95658  SubscriptionId_2643  CustomerId_3874          UGX          256
# 95659  SubscriptionId_3829  CustomerId_3874          UGX          256
# 95660   SubscriptionId_652  CustomerId_1709          UGX          256
# 95661  SubscriptionId_3829  CustomerId_1709          UGX          256
#
#          ProviderId     ProductId     ProductCategory  ... PricingStrategy  \
# 0      ProviderId_6  ProductId_10             airtime  ...               2
# 1      ProviderId_4   ProductId_6  financial_services  ...               2
# 2      ProviderId_6   ProductId_1             airtime  ...               2
# 3      ProviderId_1  ProductId_21        utility_bill  ...               2
# 4      ProviderId_4   ProductId_6  financial_services  ...               2
# ...             ...           ...                 ...  ...             ...
# 95657  ProviderId_4   ProductId_6  financial_services  ...               2
# 95658  ProviderId_6  ProductId_10             airtime  ...               2
# 95659  ProviderId_4   ProductId_6  financial_services  ...               2
# 95660  ProviderId_6  ProductId_19                  tv  ...               2
# 95661  ProviderId_4   ProductId_6  financial_services  ...               2
#
#        FraudResult  TotalTransactionAmount AverageTransactionAmount  \
# 0                0               109921.75               923.712185
# 1                0               109921.75               923.712185
# 2                0                 1000.00               500.000000
# 3                0               228727.20              6019.136842
# 4                0               228727.20              6019.136842
# ...            ...                     ...                      ...
# 95657            0              2438140.00              4255.043630
# 95658            0                58499.60              1360.455814
# 95659            0                58499.60              1360.455814
# 95660            0               851985.00              1625.925573
# 95661            0               851985.00              1625.925573
#
#        TotalTransactions  StdTransactionAmount  TransactionHour  \
# 0                    119           3042.294251                2
# 1                    119           3042.294251                2
# 2                      2              0.000000                2
# 3                     38          17169.241610                3
# 4                     38          17169.241610                3
# ...                  ...                   ...              ...
# 95657                573          22554.029939                9
# 95658                 43           2274.756582                9
# 95659                 43           2274.756582                9
# 95660                524           3207.920536               10
# 95661                524           3207.920536               10
#
#        TransactionDay  TransactionMonth  TransactionYear
# 0                  15                11             2018
# 1                  15                11             2018
# 2                  15                11             2018
# 3                  15                11             2018
# 4                  15                11             2018
# ...               ...               ...              ...
# 95657              13                 2             2019
# 95658              13                 2             2019
# 95659              13                 2             2019
# 95660              13                 2             2019
# 95661              13                 2             2019
#
# [95662 rows x 24 columns]

# %% [markdown]
# # Encoding Categorical Variables

# %% [markdown]
# Identify columns to exclude, and categorical columns to encode

# %%
# Columns to drop
cols_to_drop = ['ProductId', 'BatchId',	'AccountId','ProviderId', 'SubscriptionId', 'Value','CountryCode','CurrencyCode']
# Categorical features
cat_features = ['ProductCategory', 'ChannelId']

agg_df.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# A copy of the original DataFrame df is made to avoid modifying the original data

# %%
df_encoded = agg_df.copy().reset_index()

# %% [markdown]
# One-Hot Encoding: Converts categorical values into binary vectors.

# %%
df_encoded = pd.get_dummies(df_encoded, columns=cat_features, dtype=int)

# %% [markdown]
# Dropping TransactionStartTime column

# %%
df_encoded.drop(columns=['TransactionStartTime'], inplace=True)

# %%
df_encoded.head()
# Out:
#    index        TransactionId       CustomerId   Amount  PricingStrategy  \
# 0      0  TransactionId_76871  CustomerId_4406   1000.0                2
# 1      1  TransactionId_73770  CustomerId_4406    -20.0                2
# 2      2  TransactionId_26203  CustomerId_4683    500.0                2
# 3      3    TransactionId_380   CustomerId_988  20000.0                2
# 4      4  TransactionId_28195   CustomerId_988   -644.0                2
#
#    FraudResult  TotalTransactionAmount  AverageTransactionAmount  \
# 0            0               109921.75                923.712185
# 1            0               109921.75                923.712185
# 2            0                 1000.00                500.000000
# 3            0               228727.20               6019.136842
# 4            0               228727.20               6019.136842
#
#    TotalTransactions  StdTransactionAmount  ...  ProductCategory_movies  \
# 0                119           3042.294251  ...                       0
# 1                119           3042.294251  ...                       0
# 2                  2              0.000000  ...                       0
# 3                 38          17169.241610  ...                       0
# 4                 38          17169.241610  ...                       0
#
#    ProductCategory_other  ProductCategory_ticket  ProductCategory_transport  \
# 0                      0                       0                          0
# 1                      0                       0                          0
# 2                      0                       0                          0
# 3                      0                       0                          0
# 4                      0                       0                          0
#
#    ProductCategory_tv  ProductCategory_utility_bill  ChannelId_ChannelId_1  \
# 0                   0                             0                      0
# 1                   0                             0                      0
# 2                   0                             0                      0
# 3                   0                             1                      0
# 4                   0                             0                      0
#
#    ChannelId_ChannelId_2  ChannelId_ChannelId_3  ChannelId_ChannelId_5
# 0                      0                      1                      0
# 1                      1                      0                      0
# 2                      0                      1                      0
# 3                      0                      1                      0
# 4                      1                      0                      0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Handling Missing Values

# %% [markdown]
#     Imputation: Fill missing values using methods like mean, median, mode, or KNN imputation.
#     Removal: Remove rows or columns with missing values if they are few.

# %%
df_encoded.isnull().sum()
# Out:
# index                                   0
# TransactionId                           0
# CustomerId                              0
# Amount                                  0
# PricingStrategy                         0
# FraudResult                             0
# TotalTransactionAmount                  0
# AverageTransactionAmount                0
# TotalTransactions                       0
# StdTransactionAmount                  712
# TransactionHour                         0
# TransactionDay                          0
# TransactionMonth                        0
# TransactionYear                         0
# ProductCategory_airtime                 0
# ProductCategory_data_bundles            0
# ProductCategory_financial_services      0
# ProductCategory_movies                  0
# ProductCategory_other                   0
# ProductCategory_ticket                  0
# ProductCategory_transport               0
# ProductCategory_tv                      0
# ProductCategory_utility_bill            0
# ChannelId_ChannelId_1                   0
# ChannelId_ChannelId_2                   0
# ChannelId_ChannelId_3                   0
# ChannelId_ChannelId_5                   0
# dtype: int64

# %% [markdown]
# Filling StdTransactionAmount missing values with median

# %%
df_encoded['StdTransactionAmount'] = df_encoded['StdTransactionAmount'].fillna(df_encoded['StdTransactionAmount'].median())

# %% [markdown]
# # Normalizing/Standardizing Numerical Features

# %% [markdown]
# Normalization: Scales the data to a range of [0, 1].
#
# Standardization: Scales the data to have a mean of 0 and a standard deviation of 1.

# %%
columns_to_normalize= ['TotalTransactionAmount', 'AverageTransactionAmount']
columns_to_standardize = ['TotalTransactions', 'StdTransactionAmount']

# %% [markdown]
# Normaliation

# %%
normalize_numerical_features(df_encoded, columns_to_normalize, method = 'normalize')
# Out:
#                       index       CustomerId   Amount  PricingStrategy  \
# TransactionId
# TransactionId_76871       0  CustomerId_4406   1000.0                2
# TransactionId_73770       1  CustomerId_4406    -20.0                2
# TransactionId_26203       2  CustomerId_4683    500.0                2
# TransactionId_380         3   CustomerId_988  20000.0                2
# TransactionId_28195       4   CustomerId_988   -644.0                2
# ...                     ...              ...      ...              ...
# TransactionId_89881   95657  CustomerId_3078  -1000.0                2
# TransactionId_91597   95658  CustomerId_3874   1000.0                2
# TransactionId_82501   95659  CustomerId_3874    -20.0                2
# TransactionId_136354  95660  CustomerId_1709   3000.0                2
# TransactionId_35670   95661  CustomerId_1709    -60.0                2
#
#                       FraudResult  TotalTransactionAmount  \
# TransactionId
# TransactionId_76871             0                0.557522
# TransactionId_73770             0                0.557522
# TransactionId_26203             0                0.556944
# TransactionId_380               0                0.558153
# TransactionId_28195             0                0.558153
# ...                           ...                     ...
# TransactionId_89881             0                0.569883
# TransactionId_91597             0                0.557249
# TransactionId_82501             0                0.557249
# TransactionId_136354            0                0.561462
# TransactionId_35670             0                0.561462
#
#                       AverageTransactionAmount  TotalTransactions  \
# TransactionId
# TransactionId_76871                   0.047184                119
# TransactionId_73770                   0.047184                119
# TransactionId_26203                   0.047137                  2
# TransactionId_380                     0.047749                 38
# TransactionId_28195                   0.047749                 38
# ...                                        ...                ...
# TransactionId_89881                   0.047553                573
# TransactionId_91597                   0.047233                 43
# TransactionId_82501                   0.047233                 43
# TransactionId_136354                  0.047262                524
# TransactionId_35670                   0.047262                524
#
#                       StdTransactionAmount  TransactionHour  ...  \
# TransactionId                                                ...
# TransactionId_76871            3042.294251                2  ...
# TransactionId_73770            3042.294251                2  ...
# TransactionId_26203               0.000000                2  ...
# TransactionId_380             17169.241610                3  ...
# TransactionId_28195           17169.241610                3  ...
# ...                                    ...              ...  ...
# TransactionId_89881           22554.029939                9  ...
# TransactionId_91597            2274.756582                9  ...
# TransactionId_82501            2274.756582                9  ...
# TransactionId_136354           3207.920536               10  ...
# TransactionId_35670            3207.920536               10  ...
#
#                       ProductCategory_movies  ProductCategory_other  \
# TransactionId
# TransactionId_76871                        0                      0
# TransactionId_73770                        0                      0
# TransactionId_26203                        0                      0
# TransactionId_380                          0                      0
# TransactionId_28195                        0                      0
# ...                                      ...                    ...
# TransactionId_89881                        0                      0
# TransactionId_91597                        0                      0
# TransactionId_82501                        0                      0
# TransactionId_136354                       0                      0
# TransactionId_35670                        0                      0
#
#                       ProductCategory_ticket  ProductCategory_transport  \
# TransactionId
# TransactionId_76871                        0                          0
# TransactionId_73770                        0                          0
# TransactionId_26203                        0                          0
# TransactionId_380                          0                          0
# TransactionId_28195                        0                          0
# ...                                      ...                        ...
# TransactionId_89881                        0                          0
# TransactionId_91597                        0                          0
# TransactionId_82501                        0                          0
# TransactionId_136354                       0                          0
# TransactionId_35670                        0                          0
#
#                       ProductCategory_tv  ProductCategory_utility_bill  \
# TransactionId
# TransactionId_76871                    0                             0
# TransactionId_73770                    0                             0
# TransactionId_26203                    0                             0
# TransactionId_380                      0                             1
# TransactionId_28195                    0                             0
# ...                                  ...                           ...
# TransactionId_89881                    0                             0
# TransactionId_91597                    0                             0
# TransactionId_82501                    0                             0
# TransactionId_136354                   1                             0
# TransactionId_35670                    0                             0
#
#                       ChannelId_ChannelId_1  ChannelId_ChannelId_2  \
# TransactionId
# TransactionId_76871                       0                      0
# TransactionId_73770                       0                      1
# TransactionId_26203                       0                      0
# TransactionId_380                         0                      0
# TransactionId_28195                       0                      1
# ...                                     ...                    ...
# TransactionId_89881                       0                      1
# TransactionId_91597                       0                      0
# TransactionId_82501                       0                      1
# TransactionId_136354                      0                      0
# TransactionId_35670                       0                      1
#
#                       ChannelId_ChannelId_3  ChannelId_ChannelId_5
# TransactionId
# TransactionId_76871                       1                      0
# TransactionId_73770                       0                      0
# TransactionId_26203                       1                      0
# TransactionId_380                         1                      0
# TransactionId_28195                       0                      0
# ...                                     ...                    ...
# TransactionId_89881                       0                      0
# TransactionId_91597                       1                      0
# TransactionId_82501                       0                      0
# TransactionId_136354                      1                      0
# TransactionId_35670                       0                      0
#
# [95662 rows x 26 columns]

# %% [markdown]
# Standardizing

# %%
def standardize_columns(df, columns):
    scaler = StandardScaler()
    df[columns] = scaler.fit_transform(df[columns])
    return df

df_encoded = standardize_columns(df_encoded, columns_to_standardize)

# %%
df_encoded.head()
# Out:
#                      index       CustomerId   Amount  PricingStrategy  \
# TransactionId
# TransactionId_76871      0  CustomerId_4406   1000.0                2
# TransactionId_73770      1  CustomerId_4406    -20.0                2
# TransactionId_26203      2  CustomerId_4683    500.0                2
# TransactionId_380        3   CustomerId_988  20000.0                2
# TransactionId_28195      4   CustomerId_988   -644.0                2
#
#                      FraudResult  TotalTransactionAmount  \
# TransactionId
# TransactionId_76871            0                0.557522
# TransactionId_73770            0                0.557522
# TransactionId_26203            0                0.556944
# TransactionId_380              0                0.558153
# TransactionId_28195            0                0.558153
#
#                      AverageTransactionAmount  TotalTransactions  \
# TransactionId
# TransactionId_76871                  0.047184          -0.311831
# TransactionId_73770                  0.047184          -0.311831
# TransactionId_26203                  0.047137          -0.444993
# TransactionId_380                    0.047749          -0.404020
# TransactionId_28195                  0.047749          -0.404020
#
#                      StdTransactionAmount  TransactionHour  ...  \
# TransactionId                                               ...
# TransactionId_76871             -0.167524                2  ...
# TransactionId_73770             -0.167524                2  ...
# TransactionId_26203             -0.201719                2  ...
# TransactionId_380               -0.008737                3  ...
# TransactionId_28195             -0.008737                3  ...
#
#                      ProductCategory_movies  ProductCategory_other  \
# TransactionId
# TransactionId_76871                       0                      0
# TransactionId_73770                       0                      0
# TransactionId_26203                       0                      0
# TransactionId_380                         0                      0
# TransactionId_28195                       0                      0
#
#                      ProductCategory_ticket  ProductCategory_transport  \
# TransactionId
# TransactionId_76871                       0                          0
# TransactionId_73770                       0                          0
# TransactionId_26203                       0                          0
# TransactionId_380                         0                          0
# TransactionId_28195                       0                          0
#
#                      ProductCategory_tv  ProductCategory_utility_bill  \
# TransactionId
# TransactionId_76871                   0                             0
# TransactionId_73770                   0                             0
# TransactionId_26203                   0                             0
# TransactionId_380                     0                             1
# TransactionId_28195                   0                             0
#
#                      ChannelId_ChannelId_1  ChannelId_ChannelId_2  \
# TransactionId
# TransactionId_76871                      0                      0
# TransactionId_73770                      0                      1
# TransactionId_26203                      0                      0
# TransactionId_380                        0                      0
# TransactionId_28195                      0                      1
#
#                      ChannelId_ChannelId_3  ChannelId_ChannelId_5
# TransactionId
# TransactionId_76871                      1                      0
# TransactionId_73770                      0                      0
# TransactionId_26203                      1                      0
# TransactionId_380                        1                      0
# TransactionId_28195                      0                      0
#
# [5 rows x 26 columns]

# %% [markdown]
# Saving the data to a new csv file

# %%
df_encoded.to_csv('../data/processed_data.csv', index=False)
